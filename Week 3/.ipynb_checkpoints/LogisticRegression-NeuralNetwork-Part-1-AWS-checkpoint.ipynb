# %% [markdown]
# # Logistic Regression using Neural Network: Part -1
#
# Welcome to the 3rd Lab of 42028: Deep Learning and CNN!
#
# In this week you will be implementing some parts of a Logistic Regression classifier using Neural Network. Specifically, you will implement the activation function, and cost/loss function.
#
# So lets get started!

# %% [markdown]
# ## Binary Classification (Logistic Regression) Overview

# %% [markdown]
# ![image.png](attachment:e35d19b1-ecca-4c10-b7ea-2d7a6e8b62b0.png)

# %% [markdown]
# Activation function $a = \sigma( w^T x + b) = \frac{1}{1 + e^{-(w^T x + b)}}$
#
# Loss function $L(a, y) = -y\log a+(1-y)\log(1-a)$

# %% [markdown]
# ![image.png](attachment:68ad2868-7804-4074-9c0f-291e43959024.png)

# %% [markdown]
# ## Tasks:
#
# 1. Implement the Sigmoid activation function
# 2. Implement the Log loss cost function

# %% [markdown]
# # Task 1: Implement Sigmoid function
#
# A sigmoid function is of a form:
#
# $\sigma( w^T x + b) = \frac{1}{1 + e^{-(w^T x + b)}}$
#
# Let  $z=w^T x + b,$
#
# Hence, $\sigma(z) = \frac{1}{1 + e^{-(z)}}$
#
#
# Write a function below to calculate $\sigma(z)$ is Python.
#
# Hint:
#
# **exp(x)** --> Return e**x.
#
#
# **Reference**: https://docs.python.org/2/library/math.html

# %%
import math, numpy as np
def sigmoid(z):
    """
    Calculate the sigmoid of z

    Arguments:
    z --> A scalar or numpy array of any size.

    Return:
    result --> sigmoid(z)
    """

    ### WRITE CODE HERE ### (1 line of code)
    result = 1 / (1 + np.exp(-z))
    ### END YOUR CODE HERE ###
    
    return result

# %% [markdown]
# For, z = 0.458
#
# **[Expected Output]**
#
# sigmoid(0.458) --> 0.6125396134409151
#
# Execute the code given below to check to the output of your function.

# %%
z=0.458
print(sigmoid(z))
# Out:
# 0.6125396134409151

# %% [markdown]
# ## Task-2: Implement the negative log-likelihood loss (log loss)
#
# $L(a, y) = -y\log a+(1-y)\log(1-a)$
#
# Complete the below function to calculate L(a, y) in python
#
#
# **Hint**: Use np.log() for log

# %%
def loss(a, y):
    """
    Calculate the Loss L between actual (y) and predicted(a) value.

    Arguments:
    y --> A scalar.
    a --> A scalar.

    Return:
    result --> loss(y, a)
    """

    ### WRITE CODE HERE ### (1 line of code)
    result = (-y * np.log(a)) + ((1 - y) * np.log(1 - a))
    ### END YOUR CODE HERE ###
    
    return result

# %%
# Test your code 
print(loss(0.7, 1))
# Out:
# 0.35667494393873245
